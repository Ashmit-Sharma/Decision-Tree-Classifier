# %% [markdown]
# # GRIP: The Sparks Foundation

# %% [markdown]
# # Data Science and Business Analytics Intern

# %% [markdown]
# # Author: Ashmit Sharma

# %% [markdown]
# # Task 6: Prediction Using Decision Tree Algorithm

# %%
#Import required libraries

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pydot
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# # STEP 1: GET DATA

# %%
iris=load_iris()
X=iris.data[:,:]
y=iris.target

# %%
df=pd.DataFrame(iris['data'],columns=["Petal length","Petal Width","Sepal Length","Sepal Width"])
df['Species']=iris['target']
df['Species']=df['Species'].apply(lambda x: iris['target_names'][x])

df.head(5)
# Out:
#    Petal length  Petal Width  Sepal Length  Sepal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # STEP 2: EXPLORATORY DATA ANALYSIS

# %%
df.describe()
# Out:
#        Petal length  Petal Width  Sepal Length  Sepal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    Petal length  Petal Width  Sepal Length  Sepal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # STEP 3: DATA VISUALIZATION

# %%
sns.pairplot(data=df,hue='Species')

# %%
sns.FacetGrid(df,hue='Species',height=5,aspect=1).map(plt.scatter,'Sepal Length','Sepal Width').add_legend()

# %%
sns.FacetGrid(df,hue='Species',height=5,aspect=1).map(plt.scatter,'Petal length','Petal Width').add_legend()

# %% [markdown]
# # STEP 4: MODEL TRAINING

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#TRAINING COMPLETE

# %%
#PREDICT VALUES

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# # STEP 5: COMPARING ACTUAL AND PREDICTED FLOWER CLASSIFICATION

# %%
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})

# %%
df1.head(10)
# Out:
#    Actual  Predicted
# 0       0          0
# 1       1          1
# 2       2          2
# 3       2          2
# 4       1          1
# 5       1          1
# 6       0          0
# 7       2          2
# 8       0          0
# 9       1          2

# %% [markdown]
# # STEP 6: VISUALIZING PREDICTED DATA

# %%
df1.plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
Image(filename='img/decision_tree.png')

# %% [markdown]
# # STEP 7: SAMPLE RUN

# %%
sample=[[1,1,2,3]]

# %%
model.predict(sample)
# Out:
# array([0])

# %% [markdown]
# # STEP 8: MODEL ACCURACY

# %%
import sklearn.metrics as sm

# %%
sm.accuracy_score(y_test,y_pred)
# Out:
# 0.9333333333333333

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Prediction using decision tree algorithm was successfully carried out and model's prediction score was also found out
